# %% [markdown]
# # 🔁 Revision Checkpoint 1 — Topics 1–3
#
# **Loading · Series/DataFrame · Selection & Boolean logic.** Spaced repetition: do this without re-reading the lessons. Silent cell = pass.

# %%
import numpy as np
import pandas as pd
RAW = '../datasets/raw/'
# Mixed-skill spaced-repetition checkpoint. Asserts grade objective parts;
# interview questions have NO key — answer in writing.

# %% [markdown]
# ## Mixed question 1 — load with intent
# Load `orders.csv` keeping ids as `str`; load `order_items.csv`.

# %%
orders = ...
items = ...
assert orders['order_id'].dtype == object
assert items.shape[0] > orders.shape[0]
print('ok')

# %% [markdown]
# ## Mixed question 2 — first metric
# Add `line_revenue` to items and report the count of priced lines.

# %%
items['line_revenue'] = ...
assert items['line_revenue'].notna().sum() > 0
print(items['line_revenue'].notna().sum())

# %% [markdown]
# ## Mixed challenge — suspicious selection
# With a single `.loc` + boolean mask, select cancelled OR returned orders. Count them.

# %%
orders['status'] = orders['status'].str.strip().str.lower()
bad = ...
assert bad.dtype == bool
print('cancelled/returned:', bad.sum())

# %% [markdown]
# ## 🔢 NumPy recall (1–3)
# Pure NumPy: mask, count, nan-mean.

# %%
a = np.array([10., np.nan, 250., 5., 999.])
n_big = ...  # count > 100
m = ...        # mean ignoring nan
assert n_big == 2
assert round(m,2) == round(np.nanmean(a),2)
print('numpy ok')

# %% [markdown]
# ## 🔎 Interview questions (write answers — no key)
# - Q3: `.loc` vs `.iloc` — difference and a bug each can cause.
# - Q11: why `&`/`|` and parentheses for masks?
# - Q5: view vs copy — how do you tell, why care?

# %% [markdown]
# ## Self-rating
# Rate 1–5 your confidence on loading, the index, and boolean filtering. Anything ≤3 → redo that topic's practice.
