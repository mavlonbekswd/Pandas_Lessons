# %% [markdown]
# Data Cleaning uchun eng ko'p ishlatiladigan funksiyalar
# pd.to_datetime()
# pd.to_numeric()
# astype()
# str.strip()
# str.lower()
# dropna()
# fillna()
# replace()
# duplicated()
# drop_duplicates()
